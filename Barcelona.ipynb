# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv("../datasets/1.-Transportation/accidents-2017.csv")
# Out:
#                     Id District Name           Neighborhood Name  \
# 0      2017S008429           Unknown                     Unknown
# 1      2017S007316           Unknown                     Unknown
# 2      2017S010210           Unknown                     Unknown
# 3      2017S006364           Unknown                     Unknown
# 4      2017S004615        Sant Martí  el Camp de l'Arpa del Clot
# ...                ...           ...                         ...
# 10334  2017S003667       Sant Andreu               el Bon Pastor
# 10335  2017S001896       Sant Andreu               el Bon Pastor
# 10336  2017S010718       Sant Andreu               el Bon Pastor
# 10337  2017S006145       Sant Andreu               el Bon Pastor
# 10338  2017S000178       Sant Andreu               el Bon Pastor
#
#                                                   Street    Weekday  \
# 0      Número 27                                     ...     Friday
# ...

# %%
t=pd.read_csv("../datasets/1.-Transportation/2019_accidents_vehicles_gu_bcn_.csv")

# %%
t.shape
# Out:
# (19037, 28)

# %%
t.columns
# Out:
# Index(['Numero_expedient', 'Codi_districte', 'Nom_districte', 'Codi_barri',
#        'Nom_barri', 'Codi_carrer', 'Nom_carrer', 'Num_postal',
#        'Descripcio_dia_setmana', 'Dia_setmana', 'Descripcio_tipus_dia',
#        'NK_Any', 'Mes_any', 'Nom_mes', 'Dia_mes', 'Hora_dia',
#        'Descripcio_torn', 'Descripcio_causa_vianant',
#        'Descripcio_tipus_vehicle', 'Descripcio_model', 'Descripcio_marca',
#        'Descripcio_color', 'Descripcio_carnet', 'Antiguitat_carnet',
#        'Coordenada_UTM_X', 'Coordenada_UTM_Y', 'Longitud', 'Latitud'],
#       dtype='object')

# %%
t["Nom_barri"].value_counts()
# Out:
# la Dreta de l'Eixample             2240
# l'Antiga Esquerra de l'Eixample    1109
# Sant Gervasi - Galvany              817
# la Nova Esquerra de l'Eixample      766
# la Sagrada Família                  694
#                                    ...
# Can Baró                             25
# Torre Baró                           22
# Ciutat Meridiana                     16
# Vallbona                             13
# Can Peguera                           9
# Name: Nom_barri, Length: 74, dtype: int64

# %%
t["Nom_districte"].value_counts()
# Out:
# Eixample               5787
# Sant Martí             2449
# Sants-Montjuïc         2198
# Sarrià-Sant Gervasi    2052
# Les Corts              1289
# Sant Andreu            1209
# Horta-Guinardó         1204
# Ciutat Vella            986
# Nou Barris              979
# Gràcia                  850
# Desconegut               34
# Name: Nom_districte, dtype: int64

# %%
t["Descripcio_tipus_vehicle"].value_counts()
# Out:
# Turisme                                7420
# Motocicleta                            6064
# Furgoneta                              1228
# Ciclomotor                              951
# Bicicleta                               786
# Taxi                                    643
# Veh. mobilitat personal amb motor       486
# Autobús                                 453
# Camió rígid <= 3,5 tones                238
# Camió rígid > 3,5 tones                 180
# Tot terreny                             150
# Autobús articulat                       130
# Tractor camió                            84
# Desconegut                               58
# Veh. mobilitat personal sense motor      49
# Altres vehicles amb motor                33
# Autocar                                  22
# Maquinària d'obres i serveis             21
# Tren o tramvia                            9
# Altres vehicles sense motor               7
# Pick-up                                   5
# ...

# %%
t.head(15)
# Out:
#    Numero_expedient  Codi_districte Nom_districte  Codi_barri    Nom_barri  \
# 0   2019S005075                  -1    Desconegut          -1   Desconegut
# 1   2019S005075                  -1    Desconegut          -1   Desconegut
# 2   2019S008513                  -1    Desconegut          -1   Desconegut
# 3   2019S001554                  -1    Desconegut          -1   Desconegut
# 4   2019S001554                  -1    Desconegut          -1   Desconegut
# 5   2019S002789                  -1    Desconegut          -1   Desconegut
# 6   2019S006247                  -1    Desconegut          -1   Desconegut
# 7   2019S006247                  -1    Desconegut          -1   Desconegut
# 8   2019S009935                  -1    Desconegut          -1   Desconegut
# 9   2019S009935                  -1    Desconegut          -1   Desconegut
# 10  2019S009935                  -1    Desconegut          -1   Desconegut
# ...

# %%
p=pd.read_csv("../datasets/1.-Transportation/2019_accidents_persones_gu_bcn_.csv")

# %%
p.head()
# Out:
#   Numero_Expedient  Codi_districte        Nom_districte  Codi_barri  \
# 0  2019S003731                   5  Sarrià-Sant Gervasi          22
# 1  2019S007079                   5  Sarrià-Sant Gervasi          22
# 2  2019S000173                   5  Sarrià-Sant Gervasi          22
# 3  2019S001526                   4            Les Corts          21
# 4  2019S005025                   4            Les Corts          21
#
#                                Nom_barri  Codi_carrer  \
# 0  Vallvidrera, el Tibidabo i les Planes       700059
# 1  Vallvidrera, el Tibidabo i les Planes       700059
# 2  Vallvidrera, el Tibidabo i les Planes       107853
# 3                              Pedralbes       701267
# 4                              Pedralbes       701267
#
#                                           Num_postal Num_postal.1  \
# 0  Vallvidrera a les Planes / Vesc               ...    0050 0050
# 1  Vallvidrera a les Planes                      ...       520000
# ...

# %%
p["Nom_barri"].value_counts()
# Out:
# la Dreta de l'Eixample                   1395
# l'Antiga Esquerra de l'Eixample           666
# Sant Gervasi - Galvany                    489
# la Nova Esquerra de l'Eixample            460
# la Sagrada Família                        445
#                                          ...
# Torre Baró                                 15
# Vallvidrera, el Tibidabo i les Planes      14
# Ciutat Meridiana                            9
# Can Peguera                                 7
# Vallbona                                    5
# Name: Nom_barri, Length: 74, dtype: int64

# %%
p["Nom_districte"].value_counts()
# Out:
# Eixample               3603
# Sant Martí             1503
# Sants-Montjuïc         1377
# Sarrià-Sant Gervasi    1253
# Les Corts               832
# Horta-Guinardó          784
# Sant Andreu             781
# Ciutat Vella            585
# Nou Barris              582
# Gràcia                  525
# Desconegut               19
# Name: Nom_districte, dtype: int64

# %%
p["Edat"].value_counts()
# Out:
# 28     368
# 24     361
# 26     358
# 27     355
# 29     341
#       ...
# 97       2
# 119      2
# 96       2
# 92       1
# 95       1
# Name: Edat, Length: 100, dtype: int64

# %%
c=pd.read_csv("../datasets/1.-Transportation/CARRERER.csv")

# %%
c.head()
# Out:
#    CODI_VIA  CODI_CARRER_INE TIPUS_VIA                NOM_OFICIAL  \
# 0       102                1         C      Carrer dels Llebrencs
# 1       180                2         C       Carrer A Zona Franca
# 2       204                3         C  Carrer de Guerau de Liost
# 3       306                4         C       Carrer de l'Abat Odó
# 4       408                5         C     Carrer de l'Abat Samsó
#
#           NOM_CURT  NRE_MIN  NRE_MAX
# 0        Llebrencs      NaN      NaN
# 1    A Zona Franca      NaN      NaN
# 2  Guerau de Liost      NaN      NaN
# 3         Abat Odó      NaN      NaN
# 4       Abat Samsó      NaN      NaN

# %%
c["TIPUS_VIA"].value_counts()
# Out:
# C       2903
# Pl       531
# Ptge     387
# Jard     215
# Pg        82
# Av        80
# Camí      76
# Parc      63
# Ctra      43
# Plta      36
# Moll      32
# Jrdi      23
# Bda       23
# Pas       18
# Rda       18
# Rbla      16
# T         13
# Esc       13
# Ptja       9
# Rier       8
# Pla        7
# Via        6
# Cro        5
# Esp        4
# Gru        4
# Trav       3
# Csta       3
# G.V.       2
# Trvs       2
# Nus        1
# Escu       1
# Dav        1
# Pdis       1
# Polg       1
# Port       1
# Bar        1
# Viad       1
# Drec       1
# Name: TIPUS_VIA, dtype: int64

# %%
transports=pd.read_csv("../datasets/1.-Transportation/TRANSPORTS.csv")

# %%
transports.head(20)
# Out:
#    CODI_CAPA                     CAPA_GENERICA  \
# 0       K002  Transports i serveis relacionats
# 1       K001  Transports i serveis relacionats
# 2       K001  Transports i serveis relacionats
# 3       K001  Transports i serveis relacionats
# 4       K001  Transports i serveis relacionats
# 5       K001  Transports i serveis relacionats
# 6       K001  Transports i serveis relacionats
# 7       K001  Transports i serveis relacionats
# 8       K001  Transports i serveis relacionats
# 9       K001  Transports i serveis relacionats
# 10      K001  Transports i serveis relacionats
# 11      K001  Transports i serveis relacionats
# 12      K001  Transports i serveis relacionats
# 13      K001  Transports i serveis relacionats
# 14      K001  Transports i serveis relacionats
# 15      K011  Transports i serveis relacionats
# 16      K001  Transports i serveis relacionats
# 17      K001  Transports i serveis relacionats
# 18      K001  Transports i serveis relacionats
# ...

# %%
transports.shape
# Out:
# (651, 16)

# %%
transports["NOM_CAPA"].value_counts()
# Out:
# Metro i línies urbanes FGC        463
# Tramvia                            65
# Ferrocarrils Generalitat (FGC)     54
# RENFE                              33
# Estació marítima                   16
# Tren a l'aeroport                   9
# Funicular                           6
# Telefèric                           5
# Name: NOM_CAPA, dtype: int64
